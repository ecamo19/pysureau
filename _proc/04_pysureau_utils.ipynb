# %% [raw]
# ---
# description: 'AUTHORS: Erick Calderon-Morales'
# output-file: pysureau_utils.html
# title: pysureau utils functions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(pysureau_init)
# Out:
# ---
#
# [source](https://github.com/ecamo19/pysureau/blob/master/pysureau/pysureau_utils.py#L17){target="_blank" style="float:right; font-size:smaller"}
#
# ### pysureau_init
#
# >      pysureau_init (path:Optional[str]=None)
#
# *Function for creating the project's main folder structure alongside with the necessary parameter files*

# %%
#| echo: false
#| output: asis
show_doc(dict_to_csv)
# Out:
# ---
#
# [source](https://github.com/ecamo19/pysureau/blob/master/pysureau/pysureau_utils.py#L101){target="_blank" style="float:right; font-size:smaller"}
#
# ### dict_to_csv
#
# >      dict_to_csv (dictionary:Dict, filename:str, path:pathlib._local.Path)
#
# *Function for converting a dictionary that contains parameters into a CSV file*
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | dictionary | Dict | Dictionary |
# | filename | str | Filename |
# | path | Path | Path where the csv file will be stored |
# | **Returns** | **DataFrame** |  |

# %%
#pysureau_init(path = '/tmp')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pysureau_init(path = '/tmp')
#
# Cell In[8], line 71, in pysureau_init(path)
#      68 os.mkdir(path_to_params_folder)
#      70 # Create empty parameter files for soil
# ---> 71 create_empty_soil_parameter_files(path = path_to_params_folder)
#      73 # Create empty parameter files for climate
#      74
#      75 # Create empty parameter files for veg
#      77 os.mkdir(path_to_model_outputs_folder)
#
# File ~/Documents/projects/modelling/sureau/pysureau/pysureau/soil_utils.py:153, in create_empty_soil_parameter_files(path)
#     150 "Function for creating the CSV templates necessary for the soil parameters"
#     152 # Assert parameters ---------------------------------------------------------
# --> 153 if path is not isinstance(path, str):
#     154     raise TypeError(f'path must be a string, not {type(path).__name__}')
#     156 # Convert string to Path if provided ----------------------------------------
#
# TypeError: path must be a string, not str
