# %% [raw]
# ---
# description: 'AUTHORS: Erick Calderon-Morales'
# output-file: pysureau_init.html
# title: pysureau init
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(pysureau_init)
# Out:
# ---
#
# [source](https://github.com/ecamo19/pysureau/blob/master/pysureau/pysureau_init.py#L18){target="_blank" style="float:right; font-size:smaller"}
#
# ### pysureau_init
#
# >      pysureau_init (path:Optional[str]=None)
#
# *Function for creating the project's main folder structure alongside with the necessary parameter files*

# %%
pysureau_init(path = '/tmp')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pysureau_init(path = '/tmp')
#
# Cell In[3], line 73, in pysureau_init(path)
#      70 os.mkdir(path_to_params_folder)
#      72 # Create empty parameter files for soil
# ---> 73 create_empty_soil_parameter_files(path=path_to_params_folder)
#      75 # Create empty parameter files for climate
#      76
#      77 # Create empty parameter files for veg
#      79 os.mkdir(path_to_model_outputs_folder)
#
# File ~/Documents/projects/modelling/sureau/pysureau/pysureau/soil_utils.py:153, in create_empty_soil_parameter_files(path)
#     150 "Function for creating the CSV templates necessary for the soil parameters"
#     152 # Assert parameters ---------------------------------------------------------
# --> 153 assert isinstance(path, str) | isinstance(path, PosixPath), (
#     154     f'Input path must be a str, not a {type(path).__name__}'
#     155 )
#     157 # Convert string to Path if provided ----------------------------------------
#     158 path = Path(path)
#
# NameError: name 'PosixPath' is not defined
